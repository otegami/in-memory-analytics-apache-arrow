# %% [markdown]
# # Chapter 3
#
# If you've used `git lfs` to download the sample data files, you'll have pulled down the sliced.parquet file, run the next cell to generate the csv file from it before moving on!
#
# If you already have the `sliced.csv` file, you can skip this cell

# %%
import pyarrow as pa
import pyarrow.csv
import pyarrow.parquet as pq

# write out csv version of the parquet file that is provided in the repo

# %%
import pyspark as pyspark
from pyspark import SparkContext
conf = pyspark.SparkConf()
conf.set("spark.executor.memory", "8g")
conf.set("spark.driver.memory", "8g")
conf.set('spark.jars.packages', 'org.apache.hadoop:hadoop-aws:3.3.1')
sc = SparkContext(conf=conf)
sc._jsc.hadoopConfiguration().set('fs.s3a.aws.credentials.provider', 'org.apache.hadoop.fs.s3a.AnonymousAWSCredentialsProvider')
sc._jsc.hadoopConfiguration().set('fs.s3a.impl', 'org.apache.hadoop.fs.s3a.S3AFileSystem')

from pyspark.sql import SparkSession
spark = SparkSession(sc)

# %%
# %%timeit
import pyarrow as pa
import pyarrow.csv
import pyarrow.parquet as pq

pdf = pa.csv.read_csv('../sample_data/sliced.csv').to_pandas()
# Out:
# The slowest run took 15.19 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2.52 s ± 2.38 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %time df = spark.read.format('csv').load('../sample_data/sliced.csv', inferSchema='true', header='true')
# Out:
# CPU times: user 3.5 ms, sys: 9.25 ms, total: 12.8 ms
# Wall time: 5.96 s

# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# %%
# %time df = spark.createDataFrame(pa.csv.read_csv('../sample_data/sliced.csv').to_pandas())
# Out:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# -------------------------------------------------------------
# Py4JError                   Traceback (most recent call last)
# File <timed exec>:1
#
# File /usr/local/spark/python/pyspark/sql/session.py:873, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     871 SparkSession._activeSession = self
#     872 assert self._jvm is not None
# --> 873 self._jvm.SparkSession.setActiveSession(self._jsparkSession)
#     874 if isinstance(data, DataFrame):
#     875     raise TypeError("data is already a DataFrame")
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1722, in JVMView.__getattr__(self, name)
#    1719 _, error_message = get_error_message(answer)
#    1720 message = compute_exception_message(
#    1721     "{0} does not exist in the JVM".format(name), error_message)
# -> 1722 raise Py4JError(message)
#
# Py4JError: SparkSession does not exist in the JVM
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving

# %%
df.printSchema()
# Out:
# root
#  |-- VendorID: long (nullable = true)
#  |-- tpep_pickup_datetime: timestamp (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- pickup_longitude: double (nullable = true)
#  |-- pickup_latitude: double (nullable = true)
#  |-- RateCodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- dropoff_longitude: double (nullable = true)
#  |-- dropoff_latitude: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)

# %%
# %%time
df = spark.read.format('parquet').load('../sample_data/yellow_tripdata_2022-01.parquet') # using pyspark native reader
df.describe().show()
# Out:
# +-------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+---------------------+-----------------+--------------------+-------------------+
# |summary|          VendorID|   passenger_count|    trip_distance|        RatecodeID|store_and_fwd_flag|      PULocationID|      DOLocationID|      payment_type|       fare_amount|             extra|            mta_tax|        tip_amount|      tolls_amount|improvement_surcharge|     total_amount|congestion_surcharge|        airport_fee|
# +-------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+---------------------+-----------------+--------------------+-------------------+
# |  count|           2463931|           2392428|          2463931|           2392428|           2392428|           2463931|           2463931|           2463931|           2463931|           2463931|            2463931|           2463931|           2463931|              2463931|          2463931|             2392428|            2392428|
# |   mean| 1.707819334226486|1.3894533085217193| 5.37275119311366|1.4155067571521485|              null|166.07680937493785|163.58071553140084| 1.194449032866586|12.946484016795376|1.0067101432629406| 0.4914538921747404|2.3856955409873013|0.3749772660037505|   0.2967234066285709|19.16937009586583|   2.282322498315519|0.08249934794275941|
# | stddev|0.5021374727297668|0.9829685911276145|547.8714044600813| 5.917573265219833|              null| 65.46805744761048|  70.7901589008199|0.5001778217730759| 255.8148866371484|1.2362260656700204|0.08291560479693483| 2.830697971100425|1.6805380158244452| 0.043747407377596345|255.9640887564706|  0.7432039804760115| 0.3125554417761857|
# |    min|                 1|               0.0|              0.0|               1.0|                 N|                 1|                 1|                 0|            -480.0|              -4.5|               -0.5|           -125.22|             -31.4|                 -0.3|           -480.3|                -2.5|              -1.25|
# |    max|                 6|               9.0|        306159.28|              99.0|                 Y|               265|               265|                 5|         401092.32|              33.5|              16.59|            888.88|             193.3|                  0.3|        401095.62|                 2.5|               1.25|
# +-------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+---------------------+-----------------+--------------------+-------------------+
#
# CPU times: user 9.8 ms, sys: 1.69 ms, total: 11.5 ms
# Wall time: 23.6 s

# %%
# %%time
# df = spark.createDataFrame(pq.read_table('../sample_data/yellow_tripdata_2022-01.parquet').to_pandas()) # using pyarrow
df.describe().show()
# Out:
# -------------------------------------------------------------
# ConnectionRefusedError      Traceback (most recent call last)
# File <timed eval>:2
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:1825, in DataFrame.describe(self, *cols)
#    1823 if len(cols) == 1 and isinstance(cols[0], list):
#    1824     cols = cols[0]  # type: ignore[assignment]
# -> 1825 jdf = self._jdf.describe(self._jseq(cols))
#    1826 return DataFrame(jdf, self.sparkSession)
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:1741, in DataFrame._jseq(self, cols, converter)
#    1735 def _jseq(
#    1736     self,
#    1737     cols: Sequence,
#    1738     converter: Optional[Callable[..., Union["PrimitiveType", JavaObject]]] = None,
#    1739 ) -> JavaObject:
#    1740     """Return a JVM Seq of Columns from a list of Column or names"""
# -> 1741     return _to_seq(self.sparkSession._sc, cols, converter)
#
# File /usr/local/spark/python/pyspark/sql/column.py:88, in _to_seq(sc, cols, converter)
#      86     cols = [converter(c) for c in cols]
#      87 assert sc._jvm is not None
# ---> 88 return sc._jvm.PythonUtils.toSeq(cols)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1709, in JVMView.__getattr__(self, name)
#    1706 if name == UserHelpAutoCompletion.KEY:
#    1707     return UserHelpAutoCompletion()
# -> 1709 answer = self._gateway_client.send_command(
#    1710     proto.REFLECTION_COMMAND_NAME +
#    1711     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1712     "\n" + proto.END_COMMAND_PART)
#    1713 if answer == proto.SUCCESS_PACKAGE:
#    1714     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
# %%timeit 
df = spark.read.format('csv').load(
    '../sample_data/sliced.csv', 
    inferSchema='true', 
    header='true').select('VendorID', 
                          'tpep_pickup_datetime', 
                          'passenger_count', 
                          'tip_amount', 
                          'fare_amount', 
                          'total_amount')
# Out:
# 1.67 s ± 978 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%time
df = spark.createDataFrame(pa.csv.read_csv('../sample_data/sliced.csv',
               convert_options=pa.csv.ConvertOptions(
                include_columns=['VendorID', 'tpep_pickup_datetime',
                                 'passenger_count', 'tip_amount',
                                 'fare_amount', 'total_amount'])
               ).to_pandas())
# Out:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# --------------------------------------------------------------
# Py4JError                    Traceback (most recent call last)
# File <timed exec>:1
#
# File /usr/local/spark/python/pyspark/sql/session.py:873, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     871 SparkSession._activeSession = self
#     872 assert self._jvm is not None
# --> 873 self._jvm.SparkSession.setActiveSession(self._jsparkSession)
#     874 if isinstance(data, DataFrame):
#     875     raise TypeError("data is already a DataFrame")
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1722, in JVMView.__getattr__(self, name)
#    1719 _, error_message = get_error_message(answer)
#    1720 message = compute_exception_message(
#    1721     "{0} does not exist in the JVM".format(name), error_message)
# -> 1722 raise Py4JError(message)
#
# Py4JError: SparkSession does not exist in the JVM

# %%
import pandas as pd
from pyspark.sql.functions import * 
# import the functions we want to use like 'month', 'to_timestamp'
# and 'col'. Very useful.

df = df.withColumn('tpep_pickup_datetime',
                   to_timestamp(col('tpep_pickup_datetime'), 
                  'yyyy-MM-dd HH:mm:ss')) # the datetime format
df = df.withColumn('pickup_month', 
                   month(col('tpep_pickup_datetime')))
# Out:
# --------------------------------------------------------------
# NameError                    Traceback (most recent call last)
# Cell In [4], line 6
#       2 from pyspark.sql.functions import *
#       3 # import the functions we want to use like 'month', 'to_timestamp'
#       4 # and 'col'. Very useful.
# ----> 6 df = df.withColumn('tpep_pickup_datetime',
#       7                    to_timestamp(col('tpep_pickup_datetime'),
#       8                   'yyyy-MM-dd HH:mm:ss')) # the datetime format
#       9 df = df.withColumn('pickup_month',
#      10                    month(col('tpep_pickup_datetime')))
#
# NameError: name 'df' is not defined

# %%
# %%time

from pyspark.sql.types import * 

group_columns = ['VendorID', 'pickup_month']
non_group_cols = [col for col in df.columns if col not in group_columns]
s = StructType([f for f in df.schema.fields if f.name in non_group_cols])
cols = list([col(name) for name in non_group_cols])

df_norm = df.withColumn('values', struct(*cols))
df_norm = (df_norm.groupBy(*group_columns).agg(collect_list(df_norm.values).alias('values')))

s2 = StructType(s.fields + [StructField('v3', DoubleType())])

@udf(ArrayType(s2))
def normalize(values):
    v1 = pd.Series([r.tip_amount for r in values])
    v1_norm = (v1 - v1.mean())/v1.std()
    return [values[i] + (float(v1_norm[i]),) for i in range(0, len(values))]

df_norm = (df_norm.withColumn('new_values', normalize(df_norm.values)).drop('values').withColumn('new_values', explode(col('new_values'))))

for c in [f.name for f in s2.fields]:
    df_norm = df_norm.withColumn(c, col('new_values.{0}'.format(c)))
    
df_norm = df_norm.drop('new_values')
df_norm.show()
# Out:
# +--------+------------+--------------------+---------------+----------+-----------+------------+--------------------+
# |VendorID|pickup_month|tpep_pickup_datetime|passenger_count|tip_amount|fare_amount|total_amount|                  v3|
# +--------+------------+--------------------+---------------+----------+-----------+------------+--------------------+
# |       1|           1| 2015-01-10 20:33:38|              1|       2.0|       14.5|        17.8| 0.18341020244403536|
# |       1|           1| 2015-01-10 20:33:38|              1|       0.0|        9.5|        10.8| -0.6349579704225042|
# |       1|           1| 2015-01-10 20:33:39|              1|       0.0|        3.5|         4.8| -0.6349579704225042|
# |       1|           1| 2015-01-10 20:33:39|              1|       0.0|       15.0|        16.3| -0.6349579704225042|
# |       1|           1| 2015-01-10 20:33:39|              1|       6.7|       27.0|       40.33|  2.1065754086804036|
# |       1|           1| 2015-01-10 20:33:39|              1|       0.0|       14.0|        15.3| -0.6349579704225042|
# |       1|           1| 2015-01-10 20:33:39|              3|      1.66|        7.0|        9.96|0.044287613056723595|
# |       1|           1| 2015-01-10 20:33:39|              3|       0.0|       52.0|       58.13| -0.6349579704225042|
# |       1|           1| 2015-01-10 20:33:40|              2|      1.55|        6.5|        9.35|-7.22636450936031...|
# |       1|           1| 2015-01-10 20:33:40|              1|      1.66|        7.0|        9.96|0.044287613056723595|
# |       1|           1| 2015-01-10 20:33:41|              1|       1.0|        7.5|         9.8|-0.22577388398923443|
# |       1|           1| 2015-01-10 20:33:41|              1|       0.0|        3.0|         4.3| -0.6349579704225042|
# |       1|           1| 2015-01-10 20:33:41|              1|       3.0|       19.0|        23.3|  0.5925942888773051|
# |       1|           1| 2015-01-10 20:33:41|              1|       0.0|        6.0|         7.3| -0.6349579704225042|
# |       1|           1| 2015-01-10 19:12:21|              1|       0.0|       13.5|        14.3| -0.6349579704225042|
# |       1|           1| 2015-01-10 19:12:21|              1|      10.0|       52.0|        62.8|  3.4568828939101937|
# |       1|           1| 2015-01-04 13:44:52|              1|      2.35|       11.0|       14.15|  0.3266246326956798|
# |       1|           1| 2015-01-04 13:44:53|              2|       0.0|        5.0|         5.8| -0.6349579704225042|
# |       1|           1| 2015-01-04 13:44:53|              3|       0.0|        7.5|         8.3| -0.6349579704225042|
# |       1|           1| 2015-01-04 13:44:54|              1|      1.75|        8.0|       10.55|  0.0811141808357179|
# +--------+------------+--------------------+---------------+----------+-----------+------------+--------------------+
# only showing top 20 rows
#
# CPU times: user 43.8 ms, sys: 155 ms, total: 199 ms
# Wall time: 1min 15s

# %%
# %%time

schema = StructType(df.schema.fields + [StructField('v3', DoubleType())])

def vector_normalize(values):
    v1 = values.tip_amount
    values['v3'] = (v1 - v1.mean())/v1.std()
    return values
    
group_columns = ['VendorID', 'pickup_month']
df_pandas_norm = df.groupby(*group_columns).applyInPandas(vector_normalize, schema=schema)
df_pandas_norm.show()
# Out:
# +--------+--------------------+---------------+----------+-----------+------------+------------+--------------------+
# |VendorID|tpep_pickup_datetime|passenger_count|tip_amount|fare_amount|total_amount|pickup_month|                  v3|
# +--------+--------------------+---------------+----------+-----------+------------+------------+--------------------+
# |       1| 2015-01-10 20:33:38|              1|       2.0|       14.5|        17.8|           1| 0.18341020244403536|
# |       1| 2015-01-10 20:33:38|              1|       0.0|        9.5|        10.8|           1| -0.6349579704225042|
# |       1| 2015-01-10 20:33:39|              1|       0.0|        3.5|         4.8|           1| -0.6349579704225042|
# |       1| 2015-01-10 20:33:39|              1|       0.0|       15.0|        16.3|           1| -0.6349579704225042|
# |       1| 2015-01-10 20:33:39|              1|       6.7|       27.0|       40.33|           1|  2.1065754086804036|
# |       1| 2015-01-10 20:33:39|              1|       0.0|       14.0|        15.3|           1| -0.6349579704225042|
# |       1| 2015-01-10 20:33:39|              3|      1.66|        7.0|        9.96|           1|0.044287613056723595|
# |       1| 2015-01-10 20:33:39|              3|       0.0|       52.0|       58.13|           1| -0.6349579704225042|
# |       1| 2015-01-10 20:33:40|              2|      1.55|        6.5|        9.35|           1|-7.22636450936031...|
# |       1| 2015-01-10 20:33:40|              1|      1.66|        7.0|        9.96|           1|0.044287613056723595|
# |       1| 2015-01-10 20:33:41|              1|       1.0|        7.5|         9.8|           1|-0.22577388398923443|
# |       1| 2015-01-10 20:33:41|              1|       0.0|        3.0|         4.3|           1| -0.6349579704225042|
# |       1| 2015-01-10 20:33:41|              1|       3.0|       19.0|        23.3|           1|  0.5925942888773051|
# |       1| 2015-01-10 20:33:41|              1|       0.0|        6.0|         7.3|           1| -0.6349579704225042|
# |       1| 2015-01-10 19:12:21|              1|       0.0|       13.5|        14.3|           1| -0.6349579704225042|
# |       1| 2015-01-10 19:12:21|              1|      10.0|       52.0|        62.8|           1|  3.4568828939101937|
# |       1| 2015-01-04 13:44:52|              1|      2.35|       11.0|       14.15|           1|  0.3266246326956798|
# |       1| 2015-01-04 13:44:53|              2|       0.0|        5.0|         5.8|           1| -0.6349579704225042|
# |       1| 2015-01-04 13:44:53|              3|       0.0|        7.5|         8.3|           1| -0.6349579704225042|
# |       1| 2015-01-04 13:44:54|              1|      1.75|        8.0|       10.55|           1|  0.0811141808357179|
# +--------+--------------------+---------------+----------+-----------+------------+------------+--------------------+
# only showing top 20 rows
#
# CPU times: user 7.92 ms, sys: 3.21 ms, total: 11.1 ms
# Wall time: 2.31 s

# %% [markdown]
# ## IMPORTANT
#
# Run the next cell before loading the `perspective.ipynb` notebook. You may need to refresh this window after the cell runs before the perspective widget will load.
#
# You also might need to click the puzzle piece on the sidebar and make sure you click the `Enable` button to enable third-party jupyter extensions in order to see the widgets.

# %%
# !pip install ipywidgets
# !pip install perspective-python
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter labextension install @finos/perspective-jupyterlab
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# Out:
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (8.0.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.5.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (4.0.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (6.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.3)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.5.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.31)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.11.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.8)
# Requirement already satisfied: executing in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Collecting perspective-python
#   Downloading perspective-python-1.7.1.tar.gz (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.9/431.9 kB 3.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from perspective-python) (1.5.0)
# Collecting future>=0.16.0
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 4.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.10/site-packages (from perspective-python) (2.8.2)
# Requirement already satisfied: numpy>=1.13.1 in /opt/conda/lib/python3.10/site-packages (from perspective-python) (1.23.3)
# Collecting ipywidgets<8,>=7.5.1
#   Downloading ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.2 in /opt/conda/lib/python3.10/site-packages (from perspective-python) (5.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8,>=7.5.1->perspective-python) (6.16.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8,>=7.5.1->perspective-python) (0.2.0)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 4.1 MB/s eta 0:00:00a 0:00:01
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<8,>=7.5.1->perspective-python) (8.5.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.22.0->perspective-python) (2022.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.0->perspective-python) (1.16.0)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (1.6.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (6.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (24.0.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (5.9.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (7.3.4)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (2.13.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (3.0.31)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.5.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.18.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (5.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (6.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (4.11.1)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (0.4)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.15.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.16.0)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (7.2.1)
# Requirement already satisfied: nbclassic==0.4.5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.4.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (3.1.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.8.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (5.7.0)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.21.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets<8,>=7.5.1->perspective-python) (3.0.9)
# Requirement already satisfied: asttokens in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (2.0.8)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (0.2.2)
# Requirement already satisfied: executing in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.5.1->perspective-python) (1.1.1)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.1.1)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (5.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (4.11.1)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (2.1.1)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (2.0.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.2.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (4.16.0)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (22.1.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.4.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (3.6.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7.5.1->perspective-python) (2.21)
# Building wheels for collected packages: perspective-python, future
#   Building wheel for perspective-python (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for perspective-python (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [374 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-aarch64-cpython-310
#       creating build/lib.linux-aarch64-cpython-310/perspective
#       copying perspective/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective
#       copying perspective/libpsp.py -> build/lib.linux-aarch64-cpython-310/perspective
#       creating build/lib.linux-aarch64-cpython-310/perspective/widget
#       copying perspective/widget/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/widget
#       copying perspective/widget/widget.py -> build/lib.linux-aarch64-cpython-310/perspective/widget
#       creating build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/starlette_test.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/view_api.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/dispatch.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/table_api.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/aiohttp.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/websocket.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/client.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       copying perspective/client/tornado.py -> build/lib.linux-aarch64-cpython-310/perspective/client
#       creating build/lib.linux-aarch64-cpython-310/perspective/viewer
#       copying perspective/viewer/viewer.py -> build/lib.linux-aarch64-cpython-310/perspective/viewer
#       copying perspective/viewer/viewer_traitlets.py -> build/lib.linux-aarch64-cpython-310/perspective/viewer
#       copying perspective/viewer/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/viewer
#       copying perspective/viewer/validate.py -> build/lib.linux-aarch64-cpython-310/perspective/viewer
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests
#       copying perspective/tests/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests
#       copying perspective/tests/conftest.py -> build/lib.linux-aarch64-cpython-310/perspective/tests
#       creating build/lib.linux-aarch64-cpython-310/perspective/manager
#       copying perspective/manager/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/manager
#       copying perspective/manager/manager_internal.py -> build/lib.linux-aarch64-cpython-310/perspective/manager
#       copying perspective/manager/manager.py -> build/lib.linux-aarch64-cpython-310/perspective/manager
#       copying perspective/manager/session.py -> build/lib.linux-aarch64-cpython-310/perspective/manager
#       creating build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/table.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/view_config.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_state.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_data_formatter.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/view.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_date_validator.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_accessor.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_callback_cache.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_utils.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       copying perspective/table/_constants.py -> build/lib.linux-aarch64-cpython-310/perspective/table
#       creating build/lib.linux-aarch64-cpython-310/perspective/handlers
#       copying perspective/handlers/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/handlers
#       copying perspective/handlers/common.py -> build/lib.linux-aarch64-cpython-310/perspective/handlers
#       copying perspective/handlers/aiohttp.py -> build/lib.linux-aarch64-cpython-310/perspective/handlers
#       copying perspective/handlers/starlette.py -> build/lib.linux-aarch64-cpython-310/perspective/handlers
#       copying perspective/handlers/tornado.py -> build/lib.linux-aarch64-cpython-310/perspective/handlers
#       creating build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/aggregate.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/filters.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/plugin.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/exception.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/_version.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       copying perspective/core/sort.py -> build/lib.linux-aarch64-cpython-310/perspective/core
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/widget
#       copying perspective/tests/widget/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/widget
#       copying perspective/tests/widget/test_widget_pandas.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/widget
#       copying perspective/tests/widget/test_widget.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/widget
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/viewer
#       copying perspective/tests/viewer/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/viewer
#       copying perspective/tests/viewer/test_validate.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/viewer
#       copying perspective/tests/viewer/test_viewer.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/viewer
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/manager
#       copying perspective/tests/manager/test_manager.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/manager
#       copying perspective/tests/manager/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/manager
#       copying perspective/tests/manager/test_session.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/manager
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_exception.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_update_pandas.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_delete.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_limit.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_datetime.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_numpy.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_update_numpy.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_pandas.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_infer.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_to_format.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_view_expression.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_view.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_remove.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_object.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_ports.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_to_arrow.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_leaks.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table_arrow.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_update.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_update_arrow.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/test_table.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       copying perspective/tests/table/object_sequence.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/table
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_aiohttp_handler_chunked.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_starlette_handler.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_starlette_handler_chunked.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_tornado_lock.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_aiohttp_handler.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_aiohttp_lock.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_tornado_handler.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_starlette_lock.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_tornado_async_mode.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_aiohttp_async_mode.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_tornado_handler_chunked.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       copying perspective/tests/handlers/test_starlette_async_mode.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/handlers
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/client_mode
#       copying perspective/tests/client_mode/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/client_mode
#       copying perspective/tests/client_mode/test_client_mode.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/client_mode
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/test_threadpool.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/test_layout.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/test_sort.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/test_async.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/test_plugin.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       copying perspective/tests/core/test_aggregates.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/core
#       creating build/lib.linux-aarch64-cpython-310/perspective/core/data
#       copying perspective/core/data/__init__.py -> build/lib.linux-aarch64-cpython-310/perspective/core/data
#       copying perspective/core/data/np.py -> build/lib.linux-aarch64-cpython-310/perspective/core/data
#       copying perspective/core/data/pd.py -> build/lib.linux-aarch64-cpython-310/perspective/core/data
#       running egg_info
#       writing perspective_python.egg-info/PKG-INFO
#       writing dependency_links to perspective_python.egg-info/dependency_links.txt
#       writing requirements to perspective_python.egg-info/requires.txt
#       writing top-level names to perspective_python.egg-info/top_level.txt
#       reading manifest file 'perspective_python.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '.bumpversion.cfg'
#       warning: no files found matching 'Makefile'
#       warning: manifest_maker: MANIFEST.in, line 10: 'recursive-include' expects <dir> <pattern1> <pattern2> ...
#
#       warning: no previously-included files found matching 'docs/#*'
#       no previously-included directories found matching 'docs/build'
#       no previously-included directories found matching 'docs/gh-pages'
#       no previously-included directories found matching 'docs/dist'
#       no previously-included directories found matching 'bench'
#       warning: no directories found matching 'dist/test'
#       warning: no previously-included files matching '*~' found anywhere in distribution
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       warning: no previously-included files matching '*.pyo' found anywhere in distribution
#       warning: no previously-included files matching '.git' found anywhere in distribution
#       warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
#       warning: no previously-included files matching '.DS_Store' found anywhere in distribution
#       writing manifest file 'perspective_python.egg-info/SOURCES.txt'
#       /tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'perspective.include.perspective' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'perspective.include.perspective' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'perspective.include.perspective' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'perspective.include.perspective' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'perspective.include.perspective.python' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'perspective.include.perspective.python' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'perspective.include.perspective.python' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'perspective.include.perspective.python' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'perspective.src' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'perspective.src' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'perspective.src' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'perspective.src' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'perspective.tests.single_threaded' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'perspective.tests.single_threaded' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'perspective.tests.single_threaded' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'perspective.tests.single_threaded' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'perspective.tests.table.arrow' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'perspective.tests.table.arrow' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'perspective.tests.table.arrow' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'perspective.tests.table.arrow' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       creating build/lib.linux-aarch64-cpython-310/perspective/include
#       creating build/lib.linux-aarch64-cpython-310/perspective/include/perspective
#       copying perspective/include/perspective/python.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective
#       creating build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/accessor.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/base.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/column.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/context.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/expressions.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/fill.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/numpy.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/serialization.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/table.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/utils.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       copying perspective/include/perspective/python/view.h -> build/lib.linux-aarch64-cpython-310/perspective/include/perspective/python
#       creating build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/accessor.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/column.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/context.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/expressions.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/fill.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/numpy.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/python.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/serialization.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/table.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/utils.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       copying perspective/src/view.cpp -> build/lib.linux-aarch64-cpython-310/perspective/src
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/single_threaded
#       copying perspective/tests/single_threaded/test_single_threaded.py -> build/lib.linux-aarch64-cpython-310/perspective/tests/single_threaded
#       creating build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/date32.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/date64.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/dict.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/dict_update.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/int_float_str.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/int_float_str_file.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       copying perspective/tests/table/arrow/int_float_str_update.arrow -> build/lib.linux-aarch64-cpython-310/perspective/tests/table/arrow
#       running build_ext
#       Traceback (most recent call last):
#         File "/opt/conda/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 351, in <module>
#           main()
#         File "/opt/conda/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 333, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/opt/conda/lib/python3.10/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 249, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 412, in build_wheel
#           return self._build_with_temp_dir(['bdist_wheel'], '.whl',
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 397, in _build_with_temp_dir
#           self.run_setup()
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 483, in run_setup
#           super(_BuildMetaLegacyBackend,
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 335, in run_setup
#           exec(code, locals())
#         File "<string>", line 268, in <module>
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 968, in run_commands
#           self.run_command(cmd)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 299, in run
#           self.run_command('build')
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-99x5n8wd/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "<string>", line 108, in run
#         File "<string>", line 113, in run_cmake
#         File "/opt/conda/lib/python3.10/subprocess.py", line 420, in check_output
#           return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#         File "/opt/conda/lib/python3.10/subprocess.py", line 501, in run
#           with Popen(*popenargs, **kwargs) as process:
#         File "/opt/conda/lib/python3.10/subprocess.py", line 969, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/opt/conda/lib/python3.10/subprocess.py", line 1720, in _execute_child
#           and os.path.dirname(executable)
#         File "/opt/conda/lib/python3.10/posixpath.py", line 152, in dirname
#           p = os.fspath(p)
#       TypeError: expected str, bytes or os.PathLike object, not NoneType
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for perspective-python
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=89d5a70f4263de11ef33415dd11e3410d51193f0be8467e5c2c9c3019a0a83d9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/dc/16/09/eb08b4e34e6b638f113d2018cf0b22de1d8dca22a3a71873f7
# Successfully built future
# Failed to build perspective-python
# ERROR: Could not build wheels for perspective-python, which is required to install pyproject.toml-based projects
# Building jupyterlab assets (production, minimized)
# Building jupyterlab assets (production, minimized)
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
